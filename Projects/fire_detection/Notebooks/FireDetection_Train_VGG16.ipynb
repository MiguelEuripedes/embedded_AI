# %% [markdown]
# # Fire Detection Classifier using pre-trained VGG16 model
#
# For this porpose, this transfer learning approach explores **feature extracting** and **Fine-tuning** technics

# %% [markdown]
# # Install and Import Dependencies

# %%
# install wandb
# !pip install wandb -qU

# %%
# !pip install codecarbon

# %%
# import the necessary packages
from imutils import paths
import logging
import os
import cv2
import numpy as np
import joblib
import tensorflow as tf
import wandb
import matplotlib.pyplot as plt


from sklearn.metrics import classification_report
from sklearn.metrics import fbeta_score, precision_score, recall_score, accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

from codecarbon import EmissionsTracker

# %%
wandb.login()

# %%
# configure logging
# reference for a logging obj
logger = logging.getLogger()

# set level of logging
logger.setLevel(logging.INFO)

# create handlers
c_handler = logging.StreamHandler()
c_format = logging.Formatter(fmt="%(asctime)s %(message)s",datefmt='%d-%m-%Y %H:%M:%S')
c_handler.setFormatter(c_format)

# add handler to the logger
logger.handlers[0] = c_handler

# %% [markdown]
# # Fetch and Data Segregation

# %% [markdown]
# ## Fetch Data

# %%
args = {
    "project_name": "fire_detection_classifier",
    "artifact_name": "images_raw_data:latest"
}

# %%
# open the W&B project created in the Fetch step
run = wandb.init(entity="euripedes",project=args["project_name"], job_type="preprocessing")

# download the raw data from W&B
raw_data = run.use_artifact(args["artifact_name"])
data_dir = raw_data.download()
logger.info("Path: {}".format(data_dir))
# Out:
# wandb: Currently logged in as: euripedes. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221129_224058-1q4cw6ro</code>
# Syncing run <strong><a href="https://wandb.ai/euripedes/fire_detection_classifier/runs/1q4cw6ro" target="_blank">legendary-sound-2</a></strong> to <a href="https://wandb.ai/euripedes/fire_detection_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: Downloading large artifact images_raw_data:latest, 95.52MB. 10002 files...
# wandb:   10002 of 10002 files downloaded.
# Done. 0:1:26.4
# 29-11-2022 22:42:32 Path: ./artifacts/images_raw_data:v0

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.008 MB of 0.009 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.969673…
# Synced <strong style="color:#cdcd00">legendary-sound-2</strong>: <a href="https://wandb.ai/euripedes/fire_detection_classifier/runs/1q4cw6ro" target="_blank">https://wandb.ai/euripedes/fire_detection_classifier/runs/1q4cw6ro</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221129_224058-1q4cw6ro/logs</code>

# %% [markdown]
# Check the data directory

# %%
BATCH_SIZE = 32
IMG_SIZE = (224, 224)

raw_wb = tf.keras.utils.image_dataset_from_directory(data_dir,
                                                     shuffle=True,
                                                     batch_size=BATCH_SIZE,
                                                     image_size=IMG_SIZE,
                                                     label_mode='categorical')
# Out:
# Found 10002 files belonging to 2 classes.

# %%
type(raw_wb)
# Out:
# tensorflow.python.data.ops.dataset_ops.BatchDataset

# %%
raw_wb
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 2), dtype=tf.float32, name=None))>

# %% [markdown]
# ## Data Segregation

# %%
# 80% train, 20% validation and test
all_batches = tf.data.experimental.cardinality(raw_wb)
valtest_dataset = raw_wb.take(all_batches // 5)
train_dataset = raw_wb.skip(all_batches // 5)

valtest_batches = tf.data.experimental.cardinality(valtest_dataset)
test_dataset = valtest_dataset.take(valtest_batches // 5)
validation_dataset = valtest_dataset.skip(valtest_batches // 5)

# %%
print('Number of raw batches: %d' % tf.data.experimental.cardinality(raw_wb))
print('Number of train batches: %d' % tf.data.experimental.cardinality(train_dataset))
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of raw batches: 313
# Number of train batches: 251
# Number of validation batches: 50
# Number of test batches: 12

# %%
class_names = raw_wb.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[tf.argmax(labels[i])])
    plt.axis("off")

# %%
print(class_names)
# Out:
# ['Fire', 'Non-Fire']

# %% [markdown]
# # Configure the dataset for performance

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Using some data augmentation

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %% [markdown]
# ## Creating the pre-trained model using VGG16

# %%
args = {
  "project_name": "fire_detection_classifier"
}

# %%
run = wandb.init(entity="euripedes", project=args["project_name"], job_type="Train")
# Out:
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221129_224401-4ac9fa10</code>
# Syncing run <strong><a href="https://wandb.ai/euripedes/fire_detection_classifier/runs/4ac9fa10" target="_blank">jumping-smoke-3</a></strong> to <a href="https://wandb.ai/euripedes/fire_detection_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# Create the base model from the pre-trained model VGG16
IMG_SHAPE = IMG_SIZE + (3,)
model_vgg16 = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                         include_top=False,
                                         weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
model_vgg16.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = model_vgg16(image_batch)
print(feature_batch.shape)
# Out:
# (32, 7, 7, 512)

# %% [markdown]
# ## Feature Extraction

# %%
model_vgg16.trainable = False

# %%
model_vgg16.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 512)

# %%
prediction_layer = tf.keras.layers.Dense(2,"softmax")
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (32, 2)

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = tf.keras.applications.vgg16.preprocess_input(x)
x = model_vgg16(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.5)(x)
outputs = prediction_layer(x)
model_vgg16 = tf.keras.Model(inputs, outputs)

# %% [markdown]
# # Compile the Model

# %%
# initialize the optimizer and model
learning_rate = 0.0001
model_vgg16.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss="categorical_crossentropy",
              metrics=['accuracy'])

# %%
model_vgg16.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 2)                 1026
#
# =================================================================
# Total params: 14,715,714
# Trainable params: 1,026
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
len(model_vgg16.trainable_variables)
# Out:
# 2

# %%
tracker = EmissionsTracker(log_level="critical")
tracker.start()

print("[INFO] training head...")
history = model_vgg16.fit(train_dataset,
                    validation_data=validation_dataset,
                    batch_size=32,
                    epochs=20,
                    verbose=1)

emissions = tracker.stop()
# Out:
# [INFO] training head...
# Epoch 1/20
# 251/251 [==============================] - 60s 229ms/step - loss: 3.1788 - accuracy: 0.5286 - val_loss: 1.7578 - val_accuracy: 0.5575
# Epoch 2/20
# 251/251 [==============================] - 57s 221ms/step - loss: 2.1745 - accuracy: 0.6152 - val_loss: 0.9166 - val_accuracy: 0.7269
# Epoch 3/20
# 251/251 [==============================] - 56s 218ms/step - loss: 1.5531 - accuracy: 0.6894 - val_loss: 0.6229 - val_accuracy: 0.8000
# Epoch 4/20
# 251/251 [==============================] - 56s 219ms/step - loss: 1.1368 - accuracy: 0.7396 - val_loss: 0.4638 - val_accuracy: 0.8481
# Epoch 5/20
# 251/251 [==============================] - 57s 221ms/step - loss: 1.0093 - accuracy: 0.7680 - val_loss: 0.3559 - val_accuracy: 0.8813
# Epoch 6/20
# 251/251 [==============================] - 57s 220ms/step - loss: 0.8523 - accuracy: 0.7910 - val_loss: 0.2910 - val_accuracy: 0.8956
# Epoch 7/20
# 251/251 [==============================] - 57s 220ms/step - loss: 0.7081 - accuracy: 0.8217 - val_loss: 0.2348 - val_accuracy: 0.9262
# Epoch 8/20
# 251/251 [==============================] - 57s 220ms/step - loss: 0.6507 - accuracy: 0.8240 - val_loss: 0.2061 - val_accuracy: 0.9325
# Epoch 9/20
# 251/251 [==============================] - 56s 218ms/step - loss: 0.6401 - accuracy: 0.8301 - val_loss: 0.1881 - val_accuracy: 0.9356
# Epoch 10/20
# 251/251 [==============================] - 57s 221ms/step - loss: 0.5735 - accuracy: 0.8349 - val_loss: 0.1643 - val_accuracy: 0.9431
# Epoch 11/20
# 251/251 [==============================] - 57s 220ms/step - loss: 0.5209 - accuracy: 0.8495 - val_loss: 0.1667 - val_accuracy: 0.9444
# Epoch 12/20
# 251/251 [==============================] - 56s 218ms/step - loss: 0.4820 - accuracy: 0.8551 - val_loss: 0.1540 - val_accuracy: 0.9450
# Epoch 13/20
# 251/251 [==============================] - 56s 218ms/step - loss: 0.4493 - accuracy: 0.8611 - val_loss: 0.1431 - val_accuracy: 0.9481
# Epoch 14/20
# 251/251 [==============================] - 57s 220ms/step - loss: 0.4124 - accuracy: 0.8653 - val_loss: 0.1335 - val_accuracy: 0.9519
# Epoch 15/20
# 251/251 [==============================] - 57s 221ms/step - loss: 0.4007 - accuracy: 0.8734 - val_loss: 0.1371 - val_accuracy: 0.9556
# Epoch 16/20
# 251/251 [==============================] - 57s 221ms/step - loss: 0.3558 - accuracy: 0.8788 - val_loss: 0.1234 - val_accuracy: 0.9594
# Epoch 17/20
# 251/251 [==============================] - 57s 219ms/step - loss: 0.3351 - accuracy: 0.8828 - val_loss: 0.1180 - val_accuracy: 0.9575
# Epoch 18/20
# 251/251 [==============================] - 56s 219ms/step - loss: 0.3396 - accuracy: 0.8813 - val_loss: 0.1146 - val_accuracy: 0.9625
# Epoch 19/20
# 251/251 [==============================] - 57s 220ms/step - loss: 0.3211 - accuracy: 0.8868 - val_loss: 0.1205 - val_accuracy: 0.9619
# Epoch 20/20
# 251/251 [==============================] - 56s 218ms/step - loss: 0.3107 - accuracy: 0.8871 - val_loss: 0.1163 - val_accuracy: 0.9569

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
fig, ax = plt.subplots(1,1,figsize=(10,8))

ax.plot(np.arange(0, 20), history.history["loss"], label="train_loss",linestyle='--')
ax.plot(np.arange(0, 20), history.history["val_loss"], label="val_loss",linestyle='--')
ax.plot(np.arange(0, 20), history.history["accuracy"], label="train_acc")
ax.plot(np.arange(0, 20), history.history["val_accuracy"], label="val_acc")
ax.set_title("Training Loss and Accuracy")
ax.set_xlabel("Epoch #")
ax.set_ylabel("Loss/Accuracy")
ax.legend()
plt.show()

# %%
print("[INFO] {} kWh of electricity used since the begining".format(tracker.final_emissions_data.energy_consumed))
print("[INFO] Energy consumed for RAM: {} kWh".format(tracker.final_emissions_data.ram_energy))
print("[INFO] Energy consumed for all GPU: {} kWh".format(tracker.final_emissions_data.gpu_energy))
print("[INFO] Energy consumed for all CPU: {} kWh".format(tracker.final_emissions_data.cpu_energy))
print("[INFO] CO2 emission {}(in Kg)".format(tracker.final_emissions_data.emissions))
# Out:
# [INFO] 0.040375458925626585 kWh of electricity used since the begining
# [INFO] Energy consumed for RAM: 0.0017671527037641881 kWh
# [INFO] Energy consumed for all GPU: 0.022802137248913258 kWh
# [INFO] Energy consumed for all CPU: 0.01580616897294919 kWh
# [INFO] CO2 emission 0.005602087805785935(in Kg)

# %%
type(test_dataset)
# Out:
# tensorflow.python.data.ops.dataset_ops.PrefetchDataset

# %%
images, labels = tuple(zip(*test_dataset))
images = np.concatenate(images,axis=0)
labels = np.concatenate(labels,axis=0)

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model_vgg16.predict(images, batch_size=32)
print(classification_report(tf.argmax(labels, axis=1),
                            tf.argmax(predictions, axis=1),
                            target_names=class_names))
# Out:
# [INFO] evaluating network...
# 12/12 [==============================] - 2s 154ms/step
#               precision    recall  f1-score   support
#
#         Fire       0.92      0.97      0.95       200
#     Non-Fire       0.97      0.91      0.94       184
#
#     accuracy                           0.94       384
#    macro avg       0.94      0.94      0.94       384
# weighted avg       0.94      0.94      0.94       384

# %%
fig_confusion_matrix, ax = plt.subplots(1,1,figsize=(10,8))
ConfusionMatrixDisplay(confusion_matrix(tf.argmax(predictions, axis=1),
                                    tf.argmax(labels, axis=1)),
                  display_labels=class_names).plot(values_format=".0f",ax=ax)

ax.set_xlabel("True Label")
ax.set_ylabel("Predicted Label")
ax.grid(False)
plt.show()

# %%
plt.figure(figsize=(28,10))
for i in range(16):
  ax = plt.subplot(4, 4, i + 1)
  true = tf.argmax(labels, axis=1).numpy().astype('uint8')[i]
  pred = tf.argmax(predictions, axis=1).numpy().astype('uint8')[i]
  plt.imshow(images[i].astype('uint8'))
  plt.title("Predicted: {} / True: {}".format(class_names[pred], class_names[true]))
  plt.axis("off")

# %%
# Evaluation Metrics
logger.info("Validation Evaluation metrics")
fbeta = fbeta_score(labels.argmax(axis=1), 
                    predictions.argmax(axis=1), 
                    beta=1, zero_division=1,average='weighted')

precision = precision_score(labels.argmax(axis=1),
                            predictions.argmax(axis=1),
                            zero_division=1,average='weighted')

recall = recall_score(labels.argmax(axis=1),
                      predictions.argmax(axis=1),
                      zero_division=1,average='weighted')

acc = accuracy_score(labels.argmax(axis=1),
                     predictions.argmax(axis=1))

logger.info("Validation Accuracy: {}".format(acc))
logger.info("Validation Precision: {}".format(precision))
logger.info("Validation Recall: {}".format(recall))
logger.info("Validation F1: {}".format(fbeta))

run.summary["Acc"] = acc
run.summary["Precision"] = precision
run.summary["Recall"] = recall
run.summary["F1"] = fbeta

run.summary["Count_Params"] = model_vgg16.count_params()

run.summary["Energy_Consumed"] = tracker.final_emissions_data.energy_consumed
run.summary["Energy_RAM"] = tracker.final_emissions_data.ram_energy
run.summary["Energy_GPU"] = tracker.final_emissions_data.gpu_energy
run.summary["Energy_CPU"] = tracker.final_emissions_data.cpu_energy

run.summary["CO2_Emissions"] = tracker.final_emissions_data.emissions
# Out:
# 29-11-2022 23:11:49 Validation Evaluation metrics
# 29-11-2022 23:11:49 Validation Accuracy: 0.9427083333333334
# 29-11-2022 23:11:49 Validation Precision: 0.9437944718117132
# 29-11-2022 23:11:49 Validation Recall: 0.9427083333333334
# 29-11-2022 23:11:49 Validation F1: 0.9426068492528502

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.017 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.042568…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.94271</td></tr><tr><td>CO2_Emissions</td><td>0.0056</td></tr><tr><td>Count_Params</td><td>14715714</td></tr><tr><td>Energy_CPU</td><td>0.01581</td></tr><tr><td>Energy_Consumed</td><td>0.04038</td></tr><tr><td>Energy_GPU</td><td>0.0228</td></tr><tr><td>Energy_RAM</td><td>0.00177</td></tr><tr><td>F1</td><td>0.94261</td></tr><tr><td>Precision</td><td>0.94379</td></tr><tr><td>Recall</td><td>0.94271</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">jumping-smoke-3</strong>: <a href="https://wandb.ai/euripedes/fire_detection_classifier/runs/4ac9fa10" target="_blank">https://wandb.ai/euripedes/fire_detection_classifier/runs/4ac9fa10</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221129_224401-4ac9fa10/logs</code>

# %% [markdown]
# # Fine-Tuning the Model

# %% [markdown]
# ## Indexes and layers

# %%
# import the necessary packages
from tensorflow.keras.applications import VGG16

# whether or not to include top of CNN
include_top = 0

# load the VGG16 network
print("[INFO] loading network...")
model = VGG16(weights="imagenet", include_top= include_top > 0)
print("[INFO] showing layers...")

# loop over the layers in the network and display them to the
# console
for (i, layer) in enumerate(model.layers):
	print("[INFO] {}\t{}".format(i, layer.__class__.__name__))
# Out:
# [INFO] loading network...
# [INFO] showing layers...
# [INFO] 0	InputLayer
# [INFO] 1	Conv2D
# [INFO] 2	Conv2D
# [INFO] 3	MaxPooling2D
# [INFO] 4	Conv2D
# [INFO] 5	Conv2D
# [INFO] 6	MaxPooling2D
# [INFO] 7	Conv2D
# [INFO] 8	Conv2D
# [INFO] 9	Conv2D
# [INFO] 10	MaxPooling2D
# [INFO] 11	Conv2D
# [INFO] 12	Conv2D
# [INFO] 13	Conv2D
# [INFO] 14	MaxPooling2D
# [INFO] 15	Conv2D
# [INFO] 16	Conv2D
# [INFO] 17	Conv2D
# [INFO] 18	MaxPooling2D

# %%
# import the necessary packages
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense

# a fully connect network
class FCHeadNet:
	@staticmethod
	def build(baseModel, classes, neurons):
		# initialize the head model that will be placed on top of
		# the base, then add a FC layer
		headModel = baseModel.output
		headModel = Flatten(name="flatten")(headModel)
		headModel = Dense(neurons, activation="relu")(headModel)
		headModel = Dropout(0.5)(headModel)

		# add a softmax layer
		headModel = Dense(classes, activation="softmax")(headModel)

		# return the model
		return headModel

# %% [markdown]
# ### First Stage

# %%
args = {
  "project_name": "fire_detection_classifier"
}

# %%
run = wandb.init(entity="euripedes", project=args["project_name"], job_type="Train")
# Out:
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221129_231244-42ekk0jc</code>
# Syncing run <strong><a href="https://wandb.ai/euripedes/fire_detection_classifier/runs/42ekk0jc" target="_blank">rural-frog-4</a></strong> to <a href="https://wandb.ai/euripedes/fire_detection_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers import SGD

# %%
# Create the base model from the pre-trained model VGG16
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                         include_top=False,
                                         weights='imagenet')

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = tf.keras.applications.vgg16.preprocess_input(x)
outputs = base_model(x, training=False)
base_model = tf.keras.Model(inputs, outputs)

# %%
base_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# initialize the new head of the network, a set of FC layers
# followed by a softmax classifier
headModel = FCHeadNet.build(base_model, len(class_names), 256)

# %%
# place the head FC model on top of the base model 
# this will become the actual model we will train
ft_vgg16_model = Model(inputs=base_model.input, outputs=headModel)

# %%
ft_vgg16_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense_1 (Dense)             (None, 256)               6422784
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 21,137,986
# Trainable params: 21,137,986
# Non-trainable params: 0
# _________________________________________________________________

# %%
# loop over the layers in the network and display them to the
# console
for (i, layer) in enumerate(ft_vgg16_model.layers):
	print("[INFO] {}\t{}".format(i, layer.__class__.__name__))
# Out:
# [INFO] 0	InputLayer
# [INFO] 1	Sequential
# [INFO] 2	SlicingOpLambda
# [INFO] 3	TFOpLambda
# [INFO] 4	Functional
# [INFO] 5	Flatten
# [INFO] 6	Dense
# [INFO] 7	Dropout
# [INFO] 8	Dense

# %%
# loop over all layers in the base model and freeze them so they
# will *not* be updated during the training process
for layer in ft_vgg16_model.layers[4].layers:
	layer.trainable = False

# %%
ft_vgg16_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense_1 (Dense)             (None, 256)               6422784
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 21,137,986
# Trainable params: 6,423,298
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# RMSprop is frequently used in situations where we need to quickly obtain
# reasonable performance (as is the case when we are trying to “warm up” a set of FC layers).
opt = RMSprop(learning_rate=0.0001)

ft_vgg16_model.compile(loss="categorical_crossentropy", 
                       optimizer=opt,
                       metrics=["accuracy"])

# %%
# train the head of the network for a few epochs (all other
# layers are frozen) -- this will allow the new FC layers to
# start to become initialized with actual "learned" values
# versus pure random
tracker_1 = EmissionsTracker(log_level="critical")
tracker_1.start()

print("[INFO] training head...")
history = ft_vgg16_model.fit(train_dataset,
                    validation_data=validation_dataset,
                    batch_size=32,
                    epochs=3,
                    verbose=1)

emissions = tracker_1.stop()
# Out:
# [INFO] training head...
# Epoch 1/3
# 251/251 [==============================] - 58s 221ms/step - loss: 1.2581 - accuracy: 0.8725 - val_loss: 0.2101 - val_accuracy: 0.9638
# Epoch 2/3
# 251/251 [==============================] - 57s 222ms/step - loss: 0.3725 - accuracy: 0.9318 - val_loss: 0.1675 - val_accuracy: 0.9731
# Epoch 3/3
# 251/251 [==============================] - 57s 223ms/step - loss: 0.2690 - accuracy: 0.9510 - val_loss: 0.1645 - val_accuracy: 0.9750

# %% [markdown]
# ### Second Stage

# %%
# loop over the layers in the network and display them to the
# console
for (i, layer) in enumerate(ft_vgg16_model.layers):
	print("[INFO] {}\t{}".format(i, layer.__class__.__name__))
# Out:
# [INFO] 0	InputLayer
# [INFO] 1	Sequential
# [INFO] 2	SlicingOpLambda
# [INFO] 3	TFOpLambda
# [INFO] 4	Functional
# [INFO] 5	Flatten
# [INFO] 6	Dense
# [INFO] 7	Dropout
# [INFO] 8	Dense

# %%
# loop over the layers in the base model network and display them to the
# console
for (i, layer) in enumerate(ft_vgg16_model.layers[4].layers):
	print("[INFO] {}\t{}".format(i, layer.__class__.__name__))
# Out:
# [INFO] 0	InputLayer
# [INFO] 1	Conv2D
# [INFO] 2	Conv2D
# [INFO] 3	MaxPooling2D
# [INFO] 4	Conv2D
# [INFO] 5	Conv2D
# [INFO] 6	MaxPooling2D
# [INFO] 7	Conv2D
# [INFO] 8	Conv2D
# [INFO] 9	Conv2D
# [INFO] 10	MaxPooling2D
# [INFO] 11	Conv2D
# [INFO] 12	Conv2D
# [INFO] 13	Conv2D
# [INFO] 14	MaxPooling2D
# [INFO] 15	Conv2D
# [INFO] 16	Conv2D
# [INFO] 17	Conv2D
# [INFO] 18	MaxPooling2D

# %%
ft_vgg16_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense_1 (Dense)             (None, 256)               6422784
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 21,137,986
# Trainable params: 6,423,298
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# now that the head FC layers have been trained/initialized, lets
# unfreeze the final set of CONV layers and make them trainable
for layer in ft_vgg16_model.layers[4].layers[15:]:
	layer.trainable = True

# %%
ft_vgg16_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense_1 (Dense)             (None, 256)               6422784
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 21,137,986
# Trainable params: 13,502,722
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
# for the changes to the model to take affect we need to recompile
# the model, this time using SGD with a *very* small learning rate
print("[INFO] re-compiling model...")
opt = SGD(learning_rate=0.0001)
ft_vgg16_model.compile(loss="categorical_crossentropy", 
              optimizer=opt,
              metrics=["accuracy"])
# Out:
# [INFO] re-compiling model...

# %%
# train the model again, this time fine-tuning *both* the final set
# of CONV layers along with our set of FC layers
tracker_2 = EmissionsTracker(log_level="critical")
tracker_2.start()

print("[INFO] training head...")
history = ft_vgg16_model.fit(train_dataset,
                    validation_data=validation_dataset,
                    batch_size=32,
                    epochs=10,
                    verbose=1)

emissions = tracker_2.stop()
# Out:
# [INFO] training head...
# Epoch 1/10
# 251/251 [==============================] - 65s 244ms/step - loss: 0.1894 - accuracy: 0.9605 - val_loss: 0.1457 - val_accuracy: 0.9781
# Epoch 2/10
# 251/251 [==============================] - 61s 239ms/step - loss: 0.1620 - accuracy: 0.9630 - val_loss: 0.0951 - val_accuracy: 0.9819
# Epoch 3/10
# 251/251 [==============================] - 62s 240ms/step - loss: 0.1385 - accuracy: 0.9645 - val_loss: 0.0820 - val_accuracy: 0.9812
# Epoch 4/10
# 251/251 [==============================] - 62s 240ms/step - loss: 0.1136 - accuracy: 0.9691 - val_loss: 0.0704 - val_accuracy: 0.9837
# Epoch 5/10
# 251/251 [==============================] - 63s 239ms/step - loss: 0.1083 - accuracy: 0.9688 - val_loss: 0.0720 - val_accuracy: 0.9831
# Epoch 6/10
# 251/251 [==============================] - 62s 241ms/step - loss: 0.0984 - accuracy: 0.9688 - val_loss: 0.0788 - val_accuracy: 0.9825
# Epoch 7/10
# 251/251 [==============================] - 62s 241ms/step - loss: 0.0838 - accuracy: 0.9726 - val_loss: 0.0605 - val_accuracy: 0.9850
# Epoch 8/10
# 251/251 [==============================] - 62s 242ms/step - loss: 0.0826 - accuracy: 0.9741 - val_loss: 0.0696 - val_accuracy: 0.9806
# Epoch 9/10
# 251/251 [==============================] - 62s 242ms/step - loss: 0.0853 - accuracy: 0.9719 - val_loss: 0.0638 - val_accuracy: 0.9819
# Epoch 10/10
# 251/251 [==============================] - 64s 247ms/step - loss: 0.0880 - accuracy: 0.9744 - val_loss: 0.0652 - val_accuracy: 0.9837

# %% [markdown]
# ## Evaluation metrics

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
fig, ax = plt.subplots(1,1,figsize=(10,8))

ax.plot(np.arange(0, 10), history.history["loss"], label="train_loss",linestyle='--')
ax.plot(np.arange(0, 10), history.history["val_loss"], label="val_loss",linestyle='--')
ax.plot(np.arange(0, 10), history.history["accuracy"], label="train_acc")
ax.plot(np.arange(0, 10), history.history["val_accuracy"], label="val_acc")
ax.set_title("Training Loss and Accuracy")
ax.set_xlabel("Epoch #")
ax.set_ylabel("Loss/Accuracy")
ax.legend()
plt.show()

# %%
print("[INFO] {} kWh of electricity used since the begining".format(tracker_1.final_emissions_data.energy_consumed + 
                                                                    tracker_2.final_emissions_data.energy_consumed))

print("[INFO] Energy consumed for RAM: {} kWh".format(tracker_1.final_emissions_data.ram_energy + 
                                                      tracker_2.final_emissions_data.ram_energy))

print("[INFO] Energy consumed for all GPU: {} kWh".format(tracker_1.final_emissions_data.gpu_energy
                                                          + tracker_2.final_emissions_data.gpu_energy))

print("[INFO] Energy consumed for all CPU: {} kWh".format(tracker_1.final_emissions_data.cpu_energy + 
                                                          tracker_2.final_emissions_data.cpu_energy))

print("[INFO] CO2 emission {}(in Kg)".format(tracker_1.final_emissions_data.emissions 
                                             + tracker_2.final_emissions_data.emissions))
# Out:
# [INFO] 0.027693241301000582 kWh of electricity used since the begining
# [INFO] Energy consumed for RAM: 0.001256050853888728 kWh
# [INFO] Energy consumed for all GPU: 0.015202958768467044 kWh
# [INFO] Energy consumed for all CPU: 0.011234231678644816 kWh
# [INFO] CO2 emission 0.0038424323468569752(in Kg)

# %%
images, labels = tuple(zip(*test_dataset))
images = np.concatenate(images,axis=0)
labels = np.concatenate(labels,axis=0)

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = ft_vgg16_model.predict(images, batch_size=32)
print(classification_report(tf.argmax(labels, axis=1),
                            tf.argmax(predictions, axis=1),
                            target_names=class_names))
# Out:
# [INFO] evaluating network...
# 12/12 [==============================] - 2s 154ms/step
#               precision    recall  f1-score   support
#
#         Fire       0.98      0.98      0.98       208
#     Non-Fire       0.98      0.97      0.97       176
#
#     accuracy                           0.98       384
#    macro avg       0.98      0.98      0.98       384
# weighted avg       0.98      0.98      0.98       384

# %%
fig_confusion_matrix, ax = plt.subplots(1,1,figsize=(10,8))
ConfusionMatrixDisplay(confusion_matrix(tf.argmax(predictions, axis=1),
                                        tf.argmax(labels, axis=1)),
                       display_labels=class_names).plot(values_format=".0f",ax=ax)

ax.set_xlabel("True Label")
ax.set_ylabel("Predicted Label")
ax.grid(False)
plt.show()

# %%
# Evaluation Metrics
logger.info("Validation Evaluation metrics")
fbeta = fbeta_score(labels.argmax(axis=1), 
                    predictions.argmax(axis=1), 
                    beta=1, zero_division=1,average='weighted')

precision = precision_score(labels.argmax(axis=1),
                            predictions.argmax(axis=1),
                            zero_division=1,average='weighted')

recall = recall_score(labels.argmax(axis=1),
                      predictions.argmax(axis=1),
                      zero_division=1,average='weighted')

acc = accuracy_score(labels.argmax(axis=1),
                     predictions.argmax(axis=1))

logger.info("Validation Accuracy: {}".format(acc))
logger.info("Validation Precision: {}".format(precision))
logger.info("Validation Recall: {}".format(recall))
logger.info("Validation F1: {}".format(fbeta))

run.summary["Acc"] = acc
run.summary["Precision"] = precision
run.summary["Recall"] = recall
run.summary["F1"] = fbeta

run.summary["Count_Params"] = ft_vgg16_model.count_params()

run.summary["Energy_Consumed"] = tracker.final_emissions_data.energy_consumed
run.summary["Energy_RAM"] = tracker.final_emissions_data.ram_energy
run.summary["Energy_GPU"] = tracker.final_emissions_data.gpu_energy
run.summary["Energy_CPU"] = tracker.final_emissions_data.cpu_energy

run.summary["CO2_Emissions"] = tracker.final_emissions_data.emissions
# Out:
# 29-11-2022 23:31:15 Validation Evaluation metrics
# 29-11-2022 23:31:15 Validation Accuracy: 0.9765625
# 29-11-2022 23:31:15 Validation Precision: 0.9765652768284347
# 29-11-2022 23:31:15 Validation Recall: 0.9765625
# 29-11-2022 23:31:15 Validation F1: 0.976557215765849

# %%
plt.figure(figsize=(28,10))
for i in range(16):
  ax = plt.subplot(4, 4, i + 1)
  true = tf.argmax(labels, axis=1).numpy().astype('uint8')[i]
  pred = tf.argmax(predictions, axis=1).numpy().astype('uint8')[i]
  plt.imshow(images[i].astype('uint8'))
  plt.title("Predicted: {} / True: {}".format(class_names[pred], class_names[true]))
  plt.axis("off")

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.97656</td></tr><tr><td>CO2_Emissions</td><td>0.0056</td></tr><tr><td>Count_Params</td><td>14715714</td></tr><tr><td>Energy_CPU</td><td>0.01581</td></tr><tr><td>Energy_Consumed</td><td>0.04038</td></tr><tr><td>Energy_GPU</td><td>0.0228</td></tr><tr><td>Energy_RAM</td><td>0.00177</td></tr><tr><td>F1</td><td>0.97656</td></tr><tr><td>Precision</td><td>0.97657</td></tr><tr><td>Recall</td><td>0.97656</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">rural-frog-4</strong>: <a href="https://wandb.ai/euripedes/fire_detection_classifier/runs/42ekk0jc" target="_blank">https://wandb.ai/euripedes/fire_detection_classifier/runs/42ekk0jc</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221129_231244-42ekk0jc/logs</code>
